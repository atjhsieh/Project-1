# %%
# Import dependecies

import pandas as pd
import csv
import os
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

import plotly
import plotly.plotly as py
plotly.tools.set_credentials_file(username='jherronplahn', api_key='removed for security')

# %%
# Read in income xlsx
incomefile = os.path.join('Resources', 'median_income_yearly.xlsx')
income_df = pd.read_excel(incomefile, encoding='UTF-8')
income_df.head()
# Out:
#            State  2017 Median Income  2016 Median Income  2015 Median Income  \
# 0  United States             61372.0             59039.0             56516.0
# 1        Alabama             51113.0             47221.0             44509.0
# 2         Alaska             72231.0             75723.0             75112.0
# 3        Arizona             61125.0             57100.0             52248.0
# 4       Arkansas             48829.0             45907.0             42798.0
#
#    2014 Median Income  2013 Median Income  2012 Median Income  \
# 0             53657.0             53585.0             51017.0
# 1             42278.0             47320.0             43464.0
# 2             67629.0             72472.0             63648.0
# 3             49254.0             52611.0             47044.0
# 4             44922.0             39376.0             39018.0
#
#    2011 Median Income  2010 Median Income  2009 Median Income  \
# 0             50054.0             49276.0             49777.0
# 1             42590.0             40933.0             39980.0
# 2             57431.0             57848.0             61604.0
# 3             48621.0             46896.0             45739.0
# 4             41302.0             38587.0             36538.0
#
#    2008 Median Income  2007 Median Income  2006 Median Income  \
# 0             50303.0             50233.0             48201.0
# 1             44476.0             42212.0             37952.0
# 2             63989.0             62993.0             56418.0
# 3             46914.0             47215.0             46657.0
# 4             39586.0             40795.0             37057.0
#
#    2005 Median Income  2004 Median Income  2003 Median Income  \
# 0             46326.0             44334.0             43318.0
# 1             37150.0             36629.0             37255.0
# 2             55891.0             55063.0             51837.0
# 3             45245.0             43846.0             41166.0
# 4             36658.0             34984.0             32002.0
#
#    2002 Median Income  2001 Median Income   2000 Median Income
# 0             42409.0              42228.0             41990.0
# 1             37603.0              35160.0             35424.0
# 2             52774.0              57363.0             52847.0
# 3             39734.0              42704.0             39783.0
# 4             32387.0              33339.0             29697.0

# %%
# reorganize to include only 2000, 2005, 2010, and 2014 data
reorg_income = income_df[["State","2000 Median Income","2005 Median Income","2010 Median Income","2014 Median Income"]]
reorg_income.head()
# Out:
#            State  2000 Median Income  2005 Median Income  2010 Median Income  \
# 0  United States             41990.0             46326.0             49276.0
# 1        Alabama             35424.0             37150.0             40933.0
# 2         Alaska             52847.0             55891.0             57848.0
# 3        Arizona             39783.0             45245.0             46896.0
# 4       Arkansas             29697.0             36658.0             38587.0
#
#    2014 Median Income
# 0             53657.0
# 1             42278.0
# 2             67629.0
# 3             49254.0
# 4             44922.0

# %%
# Read in state abbbreviations from online csv into dataframe
state_codes = pd.read_csv('https://raw.githubusercontent.com/jasonong/List-of-US-States/master/states.csv')
state_codes.head(5)
# Out:
#         State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
# Merge dataframes
income_state_codes = pd.merge(reorg_income, state_codes, on='State')
income_state_codes.head()
# Out:
#         State  2000 Median Income  2005 Median Income  2010 Median Income  \
# 0     Alabama             35424.0             37150.0             40933.0
# 1      Alaska             52847.0             55891.0             57848.0
# 2     Arizona             39783.0             45245.0             46896.0
# 3    Arkansas             29697.0             36658.0             38587.0
# 4  California             46816.0             51755.0             54283.0
#
#    2014 Median Income Abbreviation
# 0             42278.0           AL
# 1             67629.0           AK
# 2             49254.0           AZ
# 3             44922.0           AR
# 4             60487.0           CA

# %%
# Calculate percentage of US total and add to dataframe

income_state_codes['Percent 2000']= income_state_codes['2000 Median Income']/income_state_codes['2000 Median Income'].sum()
income_state_codes['Percent 2005']= income_state_codes['2005 Median Income']/income_state_codes['2005 Median Income'].sum()
income_state_codes['Percent 2010']= income_state_codes['2010 Median Income']/income_state_codes['2010 Median Income'].sum()
income_state_codes['Percent 2014']= income_state_codes['2014 Median Income']/income_state_codes['2014 Median Income'].sum()

income_state_codes.head()
# Out:
#         State  2000 Median Income  2005 Median Income  2010 Median Income  \
# 0     Alabama             35424.0             37150.0             40933.0
# 1      Alaska             52847.0             55891.0             57848.0
# 2     Arizona             39783.0             45245.0             46896.0
# 3    Arkansas             29697.0             36658.0             38587.0
# 4  California             46816.0             51755.0             54283.0
#
#    2014 Median Income Abbreviation  Percent 2000  Percent 2005  Percent 2010  \
# 0             42278.0           AL      0.016960      0.016070      0.016413
# 1             67629.0           AK      0.025302      0.024177      0.023195
# 2             49254.0           AZ      0.019047      0.019572      0.018803
# 3             44922.0           AR      0.014218      0.015858      0.015472
# 4             60487.0           CA      0.022414      0.022388      0.021765
#
#    Percent 2014
# 0      0.015384
# 1      0.024609
# 2      0.017923
# 3      0.016346
# 4      0.022010

# %%
# Normalize percentage data between 0 and 1 for map comparisons 

# Create x, where x the 'scores' column's values as floats
x_2000 = income_state_codes[['Percent 2000']].values.astype(float)
x_2005 = income_state_codes[['Percent 2005']].values.astype(float)
x_2010 = income_state_codes[['Percent 2010']].values.astype(float)
x_2014 = income_state_codes[['Percent 2014']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_00_scaled = min_max_scaler.fit_transform(x_2000)
x_05_scaled = min_max_scaler.fit_transform(x_2005)
x_10_scaled = min_max_scaler.fit_transform(x_2010)
x_14_scaled = min_max_scaler.fit_transform(x_2014)

income_state_codes['Normalized 2000']= x_00_scaled
income_state_codes['Normalized 2005']= x_05_scaled
income_state_codes['Normalized 2010']= x_10_scaled
income_state_codes['Normalized 2014']= x_14_scaled

income_state_codes
# Out:
#              State 2000 Median Income 2005 Median Income 2010 Median Income  \
# 0          Alabama            35424.0            37150.0            40933.0
# 1           Alaska            52847.0            55891.0            57848.0
# 2          Arizona            39783.0            45245.0            46896.0
# 3         Arkansas            29697.0            36658.0            38587.0
# 4       California            46816.0            51755.0            54283.0
# 5         Colorado            48240.0            50449.0            60233.0
# 6      Connecticut            50172.0            56835.0            65998.0
# 7         Delaware            50365.0            51235.0            55214.0
# 8          Florida            38856.0            42990.0            44066.0
# 9          Georgia            41901.0            45926.0            44117.0
# 10          Hawaii            51546.0            59586.0            59539.0
# 11           Idaho            37611.0            44176.0            47050.0
# 12        Illinois            46064.0            48398.0            50728.0
# 13         Indiana            40865.0            42437.0            46139.0
# 14            Iowa            40991.0            46500.0            49016.0
# 42  TX<br>2010 Median Income 47266.0<br>Percent of...
# 43  UT<br>2010 Median Income 56701.0<br>Percent of...
# 44  VT<br>2010 Median Income 55928.0<br>Percent of...
# 45  VA<br>2010 Median Income 60367.0<br>Percent of...
# 46  WA<br>2010 Median Income 56163.0<br>Percent of...
# 47  WV<br>2010 Median Income 42777.0<br>Percent of...
# 48  WI<br>2010 Median Income 50351.0<br>Percent of...
# 49  WY<br>2010 Median Income 52201.0<br>Percent of...

# %%
# Choropleth US Map Plot for Year 2000 - MEDIAN HOUSEHOLD INCOME

df = income_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2000 Median Income '+df['2000 Median Income']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2000']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2000'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2000 Median Household Income - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/64.embed" height="525px" width="100%"></iframe>

# %%
# Choropleth US Map Plot for Year 2005 - MEDIAN HOUSEHOLD INCOME

df = income_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2005 Median Income '+df['2005 Median Income']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2005']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2005'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2005 Median Household Income - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/66.embed" height="525px" width="100%"></iframe>

# %%
# Choropleth US Map Plot for Year 2010 - MEDIAN HOUSEHOLD INCOME

df = income_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2010 Median Income '+df['2010 Median Income']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2010']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2010'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2010 Median Household Income - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/68.embed" height="525px" width="100%"></iframe>

# %%
# Choropleth US Map Plot for Year 2014 - MEDIAN HOUSEHOLD INCOME

df = income_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2014 Median Income '+df['2014 Median Income']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2014']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2014'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2014 Median Household Income - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/70.embed" height="525px" width="100%"></iframe>

# %%
# FROM NOTES: health respiratory data: Mortality rate for respiratory diseases from 1980-2014 (globalhealthdataexchange)
# SOURCE: http://ghdx.healthdata.org/record/united-states-chronic-respiratory-disease-mortality-rates-county-1980-2014

healthfile = os.path.join('Resources', 'us_resp_mort.xlsx')
health_df = pd.read_excel(healthfile, sheet_name='Summary', encoding='UTF-8')
health_df.head()
# Out:
#         State  Mortality Rate 2000  Mortality Rate 2005  Mortality Rate 2010  \
# 0     Alabama                65.65                69.21                70.86
# 1      Alaska                60.23                56.90                52.77
# 2     Arizona                58.24                56.44                51.18
# 3    Arkansas                62.11                65.31                66.44
# 4  California                52.14                49.25                44.59
#
#    Mortality Rate 2014
# 0                73.44
# 1                51.36
# 2                51.93
# 3                69.63
# 4                41.94

# %%
# Merge income dataframe with state codes

health_state_codes = pd.merge(health_df, state_codes, on='State')
health_state_codes.head()
# Out:
#         State  Mortality Rate 2000  Mortality Rate 2005  Mortality Rate 2010  \
# 0     Alabama                65.65                69.21                70.86
# 1      Alaska                60.23                56.90                52.77
# 2     Arizona                58.24                56.44                51.18
# 3    Arkansas                62.11                65.31                66.44
# 4  California                52.14                49.25                44.59
#
#    Mortality Rate 2014 Abbreviation
# 0                73.44           AL
# 1                51.36           AK
# 2                51.93           AZ
# 3                69.63           AR
# 4                41.94           CA

# %%
# Calculate percentage of US total and add to dataframe
health_state_codes['Percent 2000']= health_state_codes['Mortality Rate 2000']/health_state_codes['Mortality Rate 2000'].sum()
health_state_codes['Percent 2005']= health_state_codes['Mortality Rate 2005']/health_state_codes['Mortality Rate 2005'].sum()
health_state_codes['Percent 2010']= health_state_codes['Mortality Rate 2010']/health_state_codes['Mortality Rate 2010'].sum()
health_state_codes['Percent 2014']= health_state_codes['Mortality Rate 2014']/health_state_codes['Mortality Rate 2014'].sum()

health_state_codes.head()
# Out:
#         State  Mortality Rate 2000  Mortality Rate 2005  Mortality Rate 2010  \
# 0     Alabama                65.65                69.21                70.86
# 1      Alaska                60.23                56.90                52.77
# 2     Arizona                58.24                56.44                51.18
# 3    Arkansas                62.11                65.31                66.44
# 4  California                52.14                49.25                44.59
#
#    Mortality Rate 2014 Abbreviation  Percent 2000  Percent 2005  Percent 2010  \
# 0                73.44           AL      0.022550      0.023674      0.024949
# 1                51.36           AK      0.020688      0.019463      0.018579
# 2                51.93           AZ      0.020004      0.019306      0.018020
# 3                69.63           AR      0.021334      0.022340      0.023392
# 4                41.94           CA      0.017909      0.016847      0.015699
#
#    Percent 2014
# 0      0.025671
# 1      0.017953
# 2      0.018152
# 3      0.024339
# 4      0.014660

# %%
# Normalize percentage data between 0 and 1 for map scale comparisons 

# Create y, where y the 'scores' column's values as floats
y_2000 = health_state_codes[['Percent 2000']].values.astype(float)
y_2005 = health_state_codes[['Percent 2005']].values.astype(float)
y_2010 = health_state_codes[['Percent 2010']].values.astype(float)
y_2014 = health_state_codes[['Percent 2014']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
y_00_scaled = min_max_scaler.fit_transform(y_2000)
y_05_scaled = min_max_scaler.fit_transform(y_2005)
y_10_scaled = min_max_scaler.fit_transform(y_2010)
y_14_scaled = min_max_scaler.fit_transform(y_2014)

health_state_codes['Normalized 2000']= y_00_scaled
health_state_codes['Normalized 2005']= y_05_scaled
health_state_codes['Normalized 2010']= y_10_scaled
health_state_codes['Normalized 2014']= y_14_scaled

health_state_codes.head()
# Out:
#         State  Mortality Rate 2000  Mortality Rate 2005  Mortality Rate 2010  \
# 0     Alabama                65.65                69.21                70.86
# 1      Alaska                60.23                56.90                52.77
# 2     Arizona                58.24                56.44                51.18
# 3    Arkansas                62.11                65.31                66.44
# 4  California                52.14                49.25                44.59
#
#    Mortality Rate 2014 Abbreviation  Percent 2000  Percent 2005  Percent 2010  \
# 0                73.44           AL      0.022550      0.023674      0.024949
# 1                51.36           AK      0.020688      0.019463      0.018579
# 2                51.93           AZ      0.020004      0.019306      0.018020
# 3                69.63           AR      0.021334      0.022340      0.023392
# 4                41.94           CA      0.017909      0.016847      0.015699
#
#    Percent 2014  Normalized 2000  Normalized 2005  Normalized 2010  \
# 0      0.025671         0.704506         0.769076         0.827071
# 1      0.017953         0.587088         0.521888         0.471178
# 2      0.018152         0.543977         0.512651         0.439898
# 3      0.024339         0.627816         0.690763         0.740114
# 4      0.014660         0.411828         0.368273         0.310250
#
#    Normalized 2014
# 0         0.849544
# 1         0.438906
# 2         0.449507
# 3         0.778687
# 4         0.263716

# %%
# Choropleth US Map Plot for Year 2000 - MORTALITY RATE

df = health_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2000 Mortality Rate (Per 100k People) '+df['Mortality Rate 2000']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2000']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2000'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2000 Chronic Respiratory Disease Mortality Rate - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/56.embed" height="525px" width="100%"></iframe>

# %%
# Choropleth US Map Plot for Year 2005 - MORTALITY RATE

df = health_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2005 Mortality Rate (Per 100k People) '+df['Mortality Rate 2005']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2005']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2005'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2005 Chronic Respiratory Disease Mortality Rate - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/58.embed" height="525px" width="100%"></iframe>

# %%
# Choropleth US Map Plot for Year 2010 - MORTALITY RATE

df = health_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2010 Mortality Rate (Per 100k People) '+df['Mortality Rate 2010']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2010']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2010'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2010 Chronic Respiratory Disease Mortality Rate - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/60.embed" height="525px" width="100%"></iframe>

# %%
# Choropleth US Map Plot for Year 2014 - MORTALITY RATE

df = health_state_codes

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['Abbreviation'] + '<br>' +\
    '2014 Mortality Rate (Per 100k People) '+df['Mortality Rate 2014']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2014']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['Abbreviation'],
        z = df['Normalized 2014'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2014 Chronic Respiratory Disease Mortality Rate - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/62.embed" height="525px" width="100%"></iframe>

# %%
#FROM NOTES: energy source generation:annual generation of energy by state (eia.gov)
# SOURCE: https://www.eia.gov/electricity/data/state/

eiafile = os.path.join('Resources', 'eia.xls')
eai_df = pd.read_excel(eiafile, encoding='UTF-8')
eai_df.head()
# Out:
#    YEAR STATE               TYPE OF PRODUCER               ENERGY SOURCE  \
# 0  1990    AK  Total Electric Power Industry                       Total
# 1  1990    AK  Total Electric Power Industry                        Coal
# 2  1990    AK  Total Electric Power Industry  Hydroelectric Conventional
# 3  1990    AK  Total Electric Power Industry                 Natural Gas
# 4  1990    AK  Total Electric Power Industry                   Petroleum
#
#    GENERATION (Megawatthours)
# 0                   5599506.0
# 1                    510573.0
# 2                    974521.0
# 3                   3466261.0
# 4                    497116.0

# %%
#Energy generation stuff 
#isolate type of producer to Total
scotts_total_power = eai_df[eai_df["TYPE OF PRODUCER"]=="Total Electric Power Industry"]
scotts_total_power.head()
# Out:
#    YEAR STATE               TYPE OF PRODUCER               ENERGY SOURCE  \
# 0  1990    AK  Total Electric Power Industry                       Total
# 1  1990    AK  Total Electric Power Industry                        Coal
# 2  1990    AK  Total Electric Power Industry  Hydroelectric Conventional
# 3  1990    AK  Total Electric Power Industry                 Natural Gas
# 4  1990    AK  Total Electric Power Industry                   Petroleum
#
#    GENERATION (Megawatthours)
# 0                   5599506.0
# 1                    510573.0
# 2                    974521.0
# 3                   3466261.0
# 4                    497116.0

# %%
# isolate to Energy Source = Coal
coal_gen = scotts_total_power.loc[scotts_total_power["ENERGY SOURCE"] == "Coal", :]
coal_gen.head()
# Out:
#     YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 1   1990    AK  Total Electric Power Industry          Coal
# 21  1990    AL  Total Electric Power Industry          Coal
# 50  1990    AR  Total Electric Power Industry          Coal
# 76  1990    AZ  Total Electric Power Industry          Coal
# 99  1990    CA  Total Electric Power Industry          Coal
#
#     GENERATION (Megawatthours)
# 1                     510573.0
# 21                  53658115.0
# 50                  19207935.0
# 76                  31915610.0
# 99                   2637677.0

# %%
coal_gen.dtypes
# Out:
# YEAR                            int64
# STATE                          object
# TYPE OF PRODUCER               object
# ENERGY SOURCE                  object
# GENERATION (Megawatthours)    float64
# dtype: object

# %%
# Isolate to year 2000
year_2000 = coal_gen.loc[coal_gen["YEAR"] == 2000, :]
# year_2000

# drop US Total
coal_2000 = year_2000.drop(16792)
coal_2000.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 15434  2000    AK  Total Electric Power Industry          Coal
# 15455  2000    AL  Total Electric Power Industry          Coal
# 15486  2000    AR  Total Electric Power Industry          Coal
# 15516  2000    AZ  Total Electric Power Industry          Coal
# 15543  2000    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)
# 15434                    538673.0
# 15455                  77517714.0
# 15486                  24167699.0
# 15516                  40993129.0
# 15543                   2363607.0

# %%
# Calculate percent of US total
coal_2000['Percent 2000']= coal_2000['GENERATION (Megawatthours)']/coal_2000['GENERATION (Megawatthours)'].sum()
coal_2000.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 15434  2000    AK  Total Electric Power Industry          Coal
# 15455  2000    AL  Total Electric Power Industry          Coal
# 15486  2000    AR  Total Electric Power Industry          Coal
# 15516  2000    AZ  Total Electric Power Industry          Coal
# 15543  2000    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)  Percent 2000
# 15434                    538673.0      0.000274
# 15455                  77517714.0      0.039424
# 15486                  24167699.0      0.012291
# 15516                  40993129.0      0.020848
# 15543                   2363607.0      0.001202

# %%
# Normalize data for year 2000 between 0 and 1 for map comparisons 

# Create c, where c the 'scores' column's values as floats
c_2000 = coal_2000[['Percent 2000']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
c_2000_scaled = min_max_scaler.fit_transform(c_2000)


coal_2000['Normalized Percent 2000']= c_2000_scaled

coal_2000
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 15434  2000    AK  Total Electric Power Industry          Coal
# 15455  2000    AL  Total Electric Power Industry          Coal
# 15486  2000    AR  Total Electric Power Industry          Coal
# 15516  2000    AZ  Total Electric Power Industry          Coal
# 15543  2000    CA  Total Electric Power Industry          Coal
# 15598  2000    CO  Total Electric Power Industry          Coal
# 15629  2000    CT  Total Electric Power Industry          Coal
# 15667  2000    DE  Total Electric Power Industry          Coal
# 15686  2000    FL  Total Electric Power Industry          Coal
# 15728  2000    GA  Total Electric Power Industry          Coal
# 15764  2000    HI  Total Electric Power Industry          Coal
# 15793  2000    IA  Total Electric Power Industry          Coal
# 15826  2000    ID  Total Electric Power Industry          Coal
# 15848  2000    IL  Total Electric Power Industry          Coal
# 15888  2000    IN  Total Electric Power Industry          Coal
# 15920  2000    KS  Total Electric Power Industry          Coal
# 15938  2000    KY  Total Electric Power Industry          Coal
# 15958  2000    LA  Total Electric Power Industry          Coal
# 16501                129578544.0     0.06590086820644764
# 16539                 35658012.0     0.01813490009052678
# 16566                  3802760.0   0.0019340021723098756
# 16597                116212561.0     0.05910321593360978
# 16665                 39208376.0    0.019940539070765022
# 16700                  3670576.0   0.0018667762250650828
# 16710                 62219510.0       0.031643508267694
# 16749                140671964.0     0.07154274368066789
# 16857                 34491424.0     0.01754159845534848
# 16887                 39761316.0    0.020221752495003475
# 16953                  9444564.0   0.0048033026781915365
# 16996                 42302943.0     0.02151436947298826
# 17039                 91202309.0      0.0463835382000643
# 17067                 43574108.0    0.022160856727341492
#
#        Normalized Percent 2000  \
# 15434                 0.003329
# 15455                 0.550827
# 15486                 0.171386
# 15516                 0.291053
# 15543                 0.016308
# 15598                 0.251140
# 15629                 0.022158
# 15667                 0.028745
# 15686                 0.516860
# 15728                 0.569197
# 15764                 0.010725
# 15793                 0.248905
# 15826                 0.000000
# 15848                 0.585003
# 15888                 0.863486
# 15920                 0.230698
# 15938                 0.640054
# 15958                 0.166557
# 15992                 0.078830
# 16032                 0.208962
# 16069                 0.004119
# 16105                 0.485033
# 16149                 0.239524
# 16187                 0.446887
# 16213                 0.098195
# 16235                 0.114723
# 16260                 0.539645
# 16301                 0.206247
# 16319                 0.130776
# 16345                 0.027701
# 16374                 0.071261
# 16410                 0.206223
# 16432                 0.134144
# 16452                 0.177373
# 16501                 0.921100
# 16539                 0.253108
# 16566                 0.026544
# 16597                 0.826037
# 16665                 0.278359
# 16700                 0.025604
# 16710                 0.442022
# 16749                 1.000000
# 16857                 0.244811
# 16887                 0.282292
# 16953                 0.066670
# 16996                 0.300369
# 17039                 0.648156
# 17067                 0.309410
#
#                                                     text
# 15434  AK<br>GENERATION (Megawatthours) 538673.0<br>P...
# 15455  AL<br>GENERATION (Megawatthours) 77517714.0<br...
# 15486  AR<br>GENERATION (Megawatthours) 24167699.0<br...
# 15516  AZ<br>GENERATION (Megawatthours) 40993129.0<br...
# 15543  CA<br>GENERATION (Megawatthours) 2363607.0<br>...
# 15598  CO<br>GENERATION (Megawatthours) 35381219.0<br...
# 15629  CT<br>GENERATION (Megawatthours) 3186096.0<br>...
# 15667  DE<br>GENERATION (Megawatthours) 4112296.0<br>...
# 15686  FL<br>GENERATION (Megawatthours) 72741829.0<br...
# 15728  GA<br>GENERATION (Megawatthours) 80100450.0<br...
# 15764  HI<br>GENERATION (Megawatthours) 1578585.0<br>...
# 15793  IA<br>GENERATION (Megawatthours) 35067093.0<br...
# 15826  ID<br>GENERATION (Megawatthours) 70675.0<br>Pe...
# 15848  IL<br>GENERATION (Megawatthours) 82322832.0<br...
# 15888  IN<br>GENERATION (Megawatthours) 121477884.0<b...
# 15920  KS<br>GENERATION (Megawatthours) 32507051.0<br...
# 15938  KY<br>GENERATION (Megawatthours) 90063054.0<br...
# 15958  LA<br>GENERATION (Megawatthours) 23488864.0<br...
# 15992  MA<br>GENERATION (Megawatthours) 11154272.0<br...
# 16032  MD<br>GENERATION (Megawatthours) 29451065.0<br...
# 16069  ME<br>GENERATION (Megawatthours) 649748.0<br>P...
# 16105  MI<br>GENERATION (Megawatthours) 68266999.0<br...
# 16149  MN<br>GENERATION (Megawatthours) 33748088.0<br...
# 16187  MO<br>GENERATION (Megawatthours) 62903557.0<br...
# 16213  MS<br>GENERATION (Megawatthours) 13877065.0<br...
# 16235  MT<br>GENERATION (Megawatthours) 16200839.0<br...
# 16260  NC<br>GENERATION (Megawatthours) 75945463.0<br...
# 16301  ND<br>GENERATION (Megawatthours) 29069203.0<br...
# 16319  NE<br>GENERATION (Megawatthours) 18457933.0<br...
# 16345  NH<br>GENERATION (Megawatthours) 3965476.0<br>...
# 16374  NJ<br>GENERATION (Megawatthours) 10090115.0<br...
# 16410  NM<br>GENERATION (Megawatthours) 29065954.0<br...
# 16432  NV<br>GENERATION (Megawatthours) 18931521.0<br...
# 16452  NY<br>GENERATION (Megawatthours) 25009581.0<br...
# 16501  OH<br>GENERATION (Megawatthours) 129578544.0<b...
# 16539  OK<br>GENERATION (Megawatthours) 35658012.0<br...
# 16566  OR<br>GENERATION (Megawatthours) 3802760.0<br>...
# 16597  PA<br>GENERATION (Megawatthours) 116212561.0<b...
# 16665  SC<br>GENERATION (Megawatthours) 39208376.0<br...
# 16700  SD<br>GENERATION (Megawatthours) 3670576.0<br>...
# 16710  TN<br>GENERATION (Megawatthours) 62219510.0<br...
# 16749  TX<br>GENERATION (Megawatthours) 140671964.0<b...
# 16857  UT<br>GENERATION (Megawatthours) 34491424.0<br...
# 16887  VA<br>GENERATION (Megawatthours) 39761316.0<br...
# 16953  WA<br>GENERATION (Megawatthours) 9444564.0<br>...
# 16996  WI<br>GENERATION (Megawatthours) 42302943.0<br...
# 17039  WV<br>GENERATION (Megawatthours) 91202309.0<br...
# 17067  WY<br>GENERATION (Megawatthours) 43574108.0<br...

# %%
# Choropleth US Map Plot for Year 2000 - COAL POWER GENERATION

df = coal_2000

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2000']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2000'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2000 Coal Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/48.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2005
year_2005 = coal_gen.loc[coal_gen["YEAR"] == 2005, :]
# year_2005

# drop US Total
coal_2005 = year_2005.drop(25640)
coal_2005.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 24156  2005    AK  Total Electric Power Industry          Coal
# 24180  2005    AL  Total Electric Power Industry          Coal
# 24212  2005    AR  Total Electric Power Industry          Coal
# 24246  2005    AZ  Total Electric Power Industry          Coal
# 24279  2005    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)
# 24156                    624318.0
# 24180                  78128457.0
# 24212                  23037144.0
# 24246                  40143534.0
# 24279                   2135375.0

# %%
# Calculate percent of US total
coal_2005['Percent 2005']= coal_2005['GENERATION (Megawatthours)']/coal_2005['GENERATION (Megawatthours)'].sum()
coal_2005.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 24156  2005    AK  Total Electric Power Industry          Coal
# 24180  2005    AL  Total Electric Power Industry          Coal
# 24212  2005    AR  Total Electric Power Industry          Coal
# 24246  2005    AZ  Total Electric Power Industry          Coal
# 24279  2005    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)  Percent 2005
# 24156                    624318.0      0.000310
# 24180                  78128457.0      0.038814
# 24212                  23037144.0      0.011445
# 24246                  40143534.0      0.019943
# 24279                   2135375.0      0.001061

# %%
# Normalize data for year 2005 between 0 and 1 for map comparisons 

# Create c, where c the 'scores' column's values as floats
c_2005 = coal_2005[['Percent 2005']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
c_2005_scaled = min_max_scaler.fit_transform(c_2005)


coal_2005['Normalized Percent 2005']= c_2005_scaled

coal_2005.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 24156  2005    AK  Total Electric Power Industry          Coal
# 24180  2005    AL  Total Electric Power Industry          Coal
# 24212  2005    AR  Total Electric Power Industry          Coal
# 24246  2005    AZ  Total Electric Power Industry          Coal
# 24279  2005    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)  Percent 2005  Normalized Percent 2005
# 24156                    624318.0      0.000310                 0.003569
# 24180                  78128457.0      0.038814                 0.526317
# 24212                  23037144.0      0.011445                 0.154738
# 24246                  40143534.0      0.019943                 0.270117
# 24279                   2135375.0      0.001061                 0.013761

# %%
# Choropleth US Map Plot for Year 2005 - COAL POWER GENERATION

df = coal_2005

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2005']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2005'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2005 Coal Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/50.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2010
year_2010 = coal_gen.loc[coal_gen["YEAR"] == 2010, :]
# year_2010

# drop US Total
coal_2010 = year_2010.drop(34962)
coal_2010.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 33357  2010    AK  Total Electric Power Industry          Coal
# 33384  2010    AL  Total Electric Power Industry          Coal
# 33417  2010    AR  Total Electric Power Industry          Coal
# 33454  2010    AZ  Total Electric Power Industry          Coal
# 33491  2010    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)
# 33357                    620443.0
# 33384                  63050411.0
# 33417                  28152445.0
# 33454                  43643807.0
# 33491                   2100221.0

# %%
# Calculate percent of US total
coal_2010['Percent 2010']= coal_2010['GENERATION (Megawatthours)']/coal_2010['GENERATION (Megawatthours)'].sum()
coal_2010.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 33357  2010    AK  Total Electric Power Industry          Coal
# 33384  2010    AL  Total Electric Power Industry          Coal
# 33417  2010    AR  Total Electric Power Industry          Coal
# 33454  2010    AZ  Total Electric Power Industry          Coal
# 33491  2010    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)  Percent 2010
# 33357                    620443.0      0.000336
# 33384                  63050411.0      0.034131
# 33417                  28152445.0      0.015240
# 33454                  43643807.0      0.023626
# 33491                   2100221.0      0.001137

# %%
# Normalize data for year 2010 between 0 and 1 for map comparisons 

# Create c, where c the 'scores' column's values as floats
c_2010 = coal_2010[['Percent 2010']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
c_2010_scaled = min_max_scaler.fit_transform(c_2010)


coal_2010['Normalized Percent 2010']= c_2010_scaled

coal_2010.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 33357  2010    AK  Total Electric Power Industry          Coal
# 33384  2010    AL  Total Electric Power Industry          Coal
# 33417  2010    AR  Total Electric Power Industry          Coal
# 33454  2010    AZ  Total Electric Power Industry          Coal
# 33491  2010    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)  Percent 2010  Normalized Percent 2010
# 33357                    620443.0      0.000336                 0.003553
# 33384                  63050411.0      0.034131                 0.419515
# 33417                  28152445.0      0.015240                 0.186995
# 33454                  43643807.0      0.023626                 0.290212
# 33491                   2100221.0      0.001137                 0.013413

# %%
# Choropleth US Map Plot for Year 2010 - COAL POWER GENERATION

df = coal_2010

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2010']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2010'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2010 Coal Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/52.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2014
year_2014 = coal_gen.loc[coal_gen["YEAR"] == 2014, :]
# year_2014

# drop US Total
coal_2014 = year_2014.drop(42963)
coal_2014.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 41246  2014    AK  Total Electric Power Industry          Coal
# 41279  2014    AL  Total Electric Power Industry          Coal
# 41312  2014    AR  Total Electric Power Industry          Coal
# 41349  2014    AZ  Total Electric Power Industry          Coal
# 41384  2014    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)
# 41246                   558292.18
# 41279                 47301626.25
# 41312                 33220754.79
# 41349                 42665010.57
# 41384                   804759.57

# %%
# Calculate percent of US total
coal_2014['Percent 2014']= coal_2014['GENERATION (Megawatthours)']/coal_2014['GENERATION (Megawatthours)'].sum()
coal_2014.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 41246  2014    AK  Total Electric Power Industry          Coal
# 41279  2014    AL  Total Electric Power Industry          Coal
# 41312  2014    AR  Total Electric Power Industry          Coal
# 41349  2014    AZ  Total Electric Power Industry          Coal
# 41384  2014    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)  Percent 2014
# 41246                   558292.18      0.000353
# 41279                 47301626.25      0.029905
# 41312                 33220754.79      0.021003
# 41349                 42665010.57      0.026974
# 41384                   804759.57      0.000509

# %%
# Normalize data for year 2014 between 0 and 1 for map comparisons 

# Create c, where c the 'scores' column's values as floats
c_2014 = coal_2014[['Percent 2014']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
c_2014_scaled = min_max_scaler.fit_transform(c_2014)


coal_2014['Normalized Percent 2014']= c_2014_scaled

coal_2014.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 41246  2014    AK  Total Electric Power Industry          Coal
# 41279  2014    AL  Total Electric Power Industry          Coal
# 41312  2014    AR  Total Electric Power Industry          Coal
# 41349  2014    AZ  Total Electric Power Industry          Coal
# 41384  2014    CA  Total Electric Power Industry          Coal
#
#        GENERATION (Megawatthours)  Percent 2014  Normalized Percent 2014
# 41246                   558292.18      0.000353                 0.003768
# 41279                 47301626.25      0.029905                 0.319231
# 41312                 33220754.79      0.021003                 0.224201
# 41349                 42665010.57      0.026974                 0.287939
# 41384                   804759.57      0.000509                 0.005431

# %%
# Choropleth US Map Plot for Year 2014 - COAL POWER GENERATION

df = coal_2014

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2014']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2014'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2014 Coal Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/54.embed" height="525px" width="100%"></iframe>

# %%
# isolate to Energy Source = NATURAL GAS
ng_gen = scotts_total_power.loc[scotts_total_power["ENERGY SOURCE"] == "Natural Gas", :]
ng_gen.head()
# Out:
#      YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 3    1990    AK  Total Electric Power Industry   Natural Gas
# 23   1990    AL  Total Electric Power Industry   Natural Gas
# 52   1990    AR  Total Electric Power Industry   Natural Gas
# 78   1990    AZ  Total Electric Power Industry   Natural Gas
# 102  1990    CA  Total Electric Power Industry   Natural Gas
#
#      GENERATION (Megawatthours)
# 3                     3466261.0
# 23                    1020714.0
# 52                    3578573.0
# 78                    2333900.0
# 102                  74168308.0

# %%
# Isolate to year 2000
year_2000_ng = ng_gen.loc[ng_gen["YEAR"] == 2000, :]
# year_2000_ng

# drop US Total
ng_2000 = year_2000_ng.drop(16795)
# ng_2000

# %%
# Calculate percent of US total
ng_2000['Percent 2000']= ng_2000['GENERATION (Megawatthours)']/ng_2000['GENERATION (Megawatthours)'].sum()
ng_2000.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 15436  2000    AK  Total Electric Power Industry   Natural Gas
# 15457  2000    AL  Total Electric Power Industry   Natural Gas
# 15488  2000    AR  Total Electric Power Industry   Natural Gas
# 15518  2000    AZ  Total Electric Power Industry   Natural Gas
# 15546  2000    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2000
# 15436                   3975832.0      0.006615
# 15457                   5028211.0      0.008366
# 15488                   3862509.0      0.006426
# 15518                   8734799.0      0.014533
# 15546                 103218973.0      0.171734

# %%
# Normalize data for year 2000 between 0 and 1 for map comparisons 

# Create n, where n the 'scores' column's values as floats
n_2000 = ng_2000[['Percent 2000']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
n_2000_scaled = min_max_scaler.fit_transform(n_2000)


ng_2000['Normalized Percent 2000']= n_2000_scaled

ng_2000.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 15436  2000    AK  Total Electric Power Industry   Natural Gas
# 15457  2000    AL  Total Electric Power Industry   Natural Gas
# 15488  2000    AR  Total Electric Power Industry   Natural Gas
# 15518  2000    AZ  Total Electric Power Industry   Natural Gas
# 15546  2000    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2000  Normalized Percent 2000
# 15436                   3975832.0      0.006615                 0.021066
# 15457                   5028211.0      0.008366                 0.026642
# 15488                   3862509.0      0.006426                 0.020465
# 15518                   8734799.0      0.014533                 0.046281
# 15546                 103218973.0      0.171734                 0.546904

# %%
# Choropleth US Map Plot for Year 2000 - NATURAL GAS POWER GENERATION

df = ng_2000

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2000']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2000'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2000 Natural Gas Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/72.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2005
year_2005_ng = ng_gen.loc[ng_gen["YEAR"] == 2005, :]
# year_2005_ng

# drop US Total
ng_2005 = year_2005_ng.drop(25643)
# ng_2005

# %%
# Calculate percent of US total
ng_2005['Percent 2005']= ng_2005['GENERATION (Megawatthours)']/ng_2005['GENERATION (Megawatthours)'].sum()
ng_2005.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 24158  2005    AK  Total Electric Power Industry   Natural Gas
# 24182  2005    AL  Total Electric Power Industry   Natural Gas
# 24214  2005    AR  Total Electric Power Industry   Natural Gas
# 24248  2005    AZ  Total Electric Power Industry   Natural Gas
# 24282  2005    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2005
# 24158                   3723626.0      0.004893
# 24182                  13869451.0      0.018226
# 24214                   6005660.0      0.007892
# 24248                  28893013.0      0.037969
# 24282                  93353849.0      0.122679

# %%
# Normalize data for year 2005 between 0 and 1 for map comparisons 

# Create n, where n the 'scores' column's values as floats
n_2005 = ng_2005[['Percent 2005']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
n_2005_scaled = min_max_scaler.fit_transform(n_2005)


ng_2005['Normalized Percent 2005']= n_2005_scaled

ng_2005.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 24158  2005    AK  Total Electric Power Industry   Natural Gas
# 24182  2005    AL  Total Electric Power Industry   Natural Gas
# 24214  2005    AR  Total Electric Power Industry   Natural Gas
# 24248  2005    AZ  Total Electric Power Industry   Natural Gas
# 24282  2005    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2005  Normalized Percent 2005
# 24158                   3723626.0      0.004893                 0.018827
# 24182                  13869451.0      0.018226                 0.070156
# 24214                   6005660.0      0.007892                 0.030372
# 24248                  28893013.0      0.037969                 0.146162
# 24282                  93353849.0      0.122679                 0.472277

# %%
# Choropleth US Map Plot for Year 2005 - NATURAL GAS POWER GENERATION

df = ng_2005

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2005']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2005'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2005 Natural Gas Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/74.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2010
year_2010_ng = ng_gen.loc[ng_gen["YEAR"] == 2010, :]
# year_2010_ng

# drop US Total
ng_2010 = year_2010_ng.drop(34965)
# ng_2010

# %%
# Calculate percent of US total
ng_2010['Percent 2010']= ng_2010['GENERATION (Megawatthours)']/ng_2010['GENERATION (Megawatthours)'].sum()
ng_2010.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 33359  2010    AK  Total Electric Power Industry   Natural Gas
# 33386  2010    AL  Total Electric Power Industry   Natural Gas
# 33419  2010    AR  Total Electric Power Industry   Natural Gas
# 33456  2010    AZ  Total Electric Power Industry   Natural Gas
# 33494  2010    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2010
# 33359                   3750024.0      0.003797
# 33386                  39235017.0      0.039724
# 33419                  12469077.0      0.012624
# 33456                  29675942.0      0.030046
# 33494                 107522313.0      0.108862

# %%
# Normalize data for year 2010 between 0 and 1 for map comparisons 

# Create n, where n the 'scores' column's values as floats
n_2010 = ng_2010[['Percent 2010']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
n_2010_scaled = min_max_scaler.fit_transform(n_2010)


ng_2010['Normalized Percent 2010']= n_2010_scaled

ng_2010.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 33359  2010    AK  Total Electric Power Industry   Natural Gas
# 33386  2010    AL  Total Electric Power Industry   Natural Gas
# 33419  2010    AR  Total Electric Power Industry   Natural Gas
# 33456  2010    AZ  Total Electric Power Industry   Natural Gas
# 33494  2010    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2010  Normalized Percent 2010
# 33359                   3750024.0      0.003797                 0.020046
# 33386                  39235017.0      0.039724                 0.209929
# 33419                  12469077.0      0.012624                 0.066703
# 33456                  29675942.0      0.030046                 0.158778
# 33494                 107522313.0      0.108862                 0.575339

# %%
# Choropleth US Map Plot for Year 2010 - NATURAL GAS POWER GENERATION

df = ng_2010

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2010']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2010'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2010 Natural Gas Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/76.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2014
year_2014_ng = ng_gen.loc[ng_gen["YEAR"] == 2014, :]
# year_2014_ng

# drop US Total
ng_2014 = year_2014_ng.drop(42967)
# ng_2014

# %%
# Calculate percent of US total
ng_2014['Percent 2014']= ng_2014['GENERATION (Megawatthours)']/ng_2014['GENERATION (Megawatthours)'].sum()
ng_2014.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 41248  2014    AK  Total Electric Power Industry   Natural Gas
# 41281  2014    AL  Total Electric Power Industry   Natural Gas
# 41315  2014    AR  Total Electric Power Industry   Natural Gas
# 41352  2014    AZ  Total Electric Power Industry   Natural Gas
# 41388  2014    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2014
# 41248                3.288022e+06      0.002919
# 41281                4.827007e+07      0.042845
# 41315                9.613708e+06      0.008533
# 41352                2.724188e+07      0.024180
# 41388                1.204264e+08      0.106893

# %%
# Normalize data for year 2014 between 0 and 1 for map comparisons 

# Create n, where n the 'scores' column's values as floats
n_2014 = ng_2014[['Percent 2014']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
n_2014_scaled = min_max_scaler.fit_transform(n_2014)


ng_2014['Normalized Percent 2014']= n_2014_scaled

ng_2014.head()
# Out:
#        YEAR STATE               TYPE OF PRODUCER ENERGY SOURCE  \
# 41248  2014    AK  Total Electric Power Industry   Natural Gas
# 41281  2014    AL  Total Electric Power Industry   Natural Gas
# 41315  2014    AR  Total Electric Power Industry   Natural Gas
# 41352  2014    AZ  Total Electric Power Industry   Natural Gas
# 41388  2014    CA  Total Electric Power Industry   Natural Gas
#
#        GENERATION (Megawatthours)  Percent 2014  Normalized Percent 2014
# 41248                3.288022e+06      0.002919                 0.016049
# 41281                4.827007e+07      0.042845                 0.235775
# 41315                9.613708e+06      0.008533                 0.046949
# 41352                2.724188e+07      0.024180                 0.133058
# 41388                1.204264e+08      0.106893                 0.588241

# %%
# Choropleth US Map Plot for Year 2014 - NATURAL GAS POWER GENERATION

df = ng_2014

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['STATE'] + '<br>' +\
    'GENERATION (Megawatthours) '+df['GENERATION (Megawatthours)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2014']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['STATE'],
        z = df['Normalized Percent 2014'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2014 Natural Gas Power Generation - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/78.embed" height="525px" width="100%"></iframe>

# %%
emissionsfile = os.path.join('Resources', 'targetyears_emissiondata.xlsx')
emissions_df = pd.read_excel(emissionsfile, encoding='UTF-8')
emissions_df.head()
# Out:
#    Year State abbreviation  State annual NOx emissions (tons)  \
# 0  2000                 AK                          14978.584
# 1  2000                 AL                         189508.640
# 2  2000                 AR                          53543.838
# 3  2000                 AZ                         104220.977
# 4  2000                 CA                          58741.984
#
#    State annual SO2 emissions (tons)  State annual CO2 emissions (tons)  \
# 0                           4151.465                       3.975039e+06
# 1                         515083.663                       8.993231e+07
# 2                          76510.438                       3.208581e+07
# 3                          72401.525                       5.227386e+07
# 4                          17917.106                       6.595547e+07
#
#    State annual CH4 emissions (lbs)  State annual N2O emissions (lbs)
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN

# %%
emissions_df.dtypes
# Out:
# Year                                   int64
# State abbreviation                    object
# State annual NOx emissions (tons)    float64
# State annual SO2 emissions (tons)    float64
# State annual CO2 emissions (tons)    float64
# State annual CH4 emissions (lbs)     float64
# State annual N2O emissions (lbs)     float64
# dtype: object

# %%
# reorganize to include only CO2 data
reorg_em = emissions_df[["Year","State abbreviation","State annual CO2 emissions (tons)"]]
reorg_em.head()
# Out:
#    Year State abbreviation  State annual CO2 emissions (tons)
# 0  2000                 AK                       3.975039e+06
# 1  2000                 AL                       8.993231e+07
# 2  2000                 AR                       3.208581e+07
# 3  2000                 AZ                       5.227386e+07
# 4  2000                 CA                       6.595547e+07

# %%
# Isolate to year 2000
em_2000 = reorg_em.loc[reorg_em["Year"] == 2000, :]
em_2000.head()
# Out:
#    Year State abbreviation  State annual CO2 emissions (tons)
# 0  2000                 AK                       3.975039e+06
# 1  2000                 AL                       8.993231e+07
# 2  2000                 AR                       3.208581e+07
# 3  2000                 AZ                       5.227386e+07
# 4  2000                 CA                       6.595547e+07

# %%
# Calculate percent of US total
em_2000['Percent 2000']= em_2000['State annual CO2 emissions (tons)']/em_2000['State annual CO2 emissions (tons)'].sum()
em_2000.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Year State abbreviation  State annual CO2 emissions (tons)  Percent 2000
# 0  2000                 AK                       3.975039e+06      0.001498
# 1  2000                 AL                       8.993231e+07      0.033900
# 2  2000                 AR                       3.208581e+07      0.012095
# 3  2000                 AZ                       5.227386e+07      0.019704
# 4  2000                 CA                       6.595547e+07      0.024862

# %%
# Normalize data for year 2000 between 0 and 1 for map comparisons 

# Create e, where e the 'scores' column's values as floats
e_2000 = em_2000[['Percent 2000']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
e_2000_scaled = min_max_scaler.fit_transform(e_2000)


em_2000['Normalized Percent 2000']= e_2000_scaled

em_2000.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Year State abbreviation  State annual CO2 emissions (tons)  Percent 2000  \
# 0  2000                 AK                       3.975039e+06      0.001498
# 1  2000                 AL                       8.993231e+07      0.033900
# 2  2000                 AR                       3.208581e+07      0.012095
# 3  2000                 AZ                       5.227386e+07      0.019704
# 4  2000                 CA                       6.595547e+07      0.024862
#
#    Normalized Percent 2000
# 0                 0.013645
# 1                 0.322664
# 2                 0.114704
# 3                 0.187281
# 4                 0.236466

# %%
# Choropleth US Map Plot for Year 2000 - CO2 EMISSIONS

df = em_2000

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['State abbreviation'] + '<br>' +\
    'State annual CO2 emissions (tons) '+df['State annual CO2 emissions (tons)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2000']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['State abbreviation'],
        z = df['Normalized Percent 2000'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2000 CO2 Emissions - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/80.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2005
em_2005 = reorg_em.loc[reorg_em["Year"] == 2005, :]
em_2005.head()
# Out:
#     Year State abbreviation  State annual CO2 emissions (tons)
# 51  2005                 AK                       3.583599e+06
# 52  2005                 AL                       9.204392e+07
# 53  2005                 AR                       2.937520e+07
# 54  2005                 AZ                       5.877819e+07
# 55  2005                 CA                       5.398590e+07

# %%
# Calculate percent of US total
em_2005['Percent 2005']= em_2005['State annual CO2 emissions (tons)']/em_2005['State annual CO2 emissions (tons)'].sum()
em_2005.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Year State abbreviation  State annual CO2 emissions (tons)  Percent 2005
# 51  2005                 AK                       3.583599e+06      0.001329
# 52  2005                 AL                       9.204392e+07      0.034138
# 53  2005                 AR                       2.937520e+07      0.010895
# 54  2005                 AZ                       5.877819e+07      0.021800
# 55  2005                 CA                       5.398590e+07      0.020023

# %%
# Normalize data for year 2005 between 0 and 1 for map comparisons 

# Create e, where e the 'scores' column's values as floats
e_2005 = em_2005[['Percent 2005']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
e_2005_scaled = min_max_scaler.fit_transform(e_2005)


em_2005['Normalized Percent 2005']= e_2005_scaled

em_2005.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Year State abbreviation  State annual CO2 emissions (tons)  Percent 2005  \
# 51  2005                 AK                       3.583599e+06      0.001329
# 52  2005                 AL                       9.204392e+07      0.034138
# 53  2005                 AR                       2.937520e+07      0.010895
# 54  2005                 AZ                       5.877819e+07      0.021800
# 55  2005                 CA                       5.398590e+07      0.020023
#
#     Normalized Percent 2005
# 51                 0.013263
# 52                 0.341878
# 53                 0.109074
# 54                 0.218302
# 55                 0.200499

# %%
# Choropleth US Map Plot for Year 2005 - CO2 EMISSIONS

df = em_2005

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['State abbreviation'] + '<br>' +\
    'State annual CO2 emissions (tons) '+df['State annual CO2 emissions (tons)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2005']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['State abbreviation'],
        z = df['Normalized Percent 2005'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2005 CO2 Emissions - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/82.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2010
em_2010 = reorg_em.loc[reorg_em["Year"] == 2010, :]
em_2010.head()
# Out:
#      Year State abbreviation  State annual CO2 emissions (tons)
# 102  2010                 AK                       3.668216e+06
# 103  2010                 AL                       8.571505e+07
# 104  2010                 AR                       3.616419e+07
# 105  2010                 AZ                       6.105057e+07
# 106  2010                 CA                       5.222043e+07

# %%
# Calculate percent of US total
em_2010['Percent 2010']= em_2010['State annual CO2 emissions (tons)']/em_2010['State annual CO2 emissions (tons)'].sum()
em_2010.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Year State abbreviation  State annual CO2 emissions (tons)  Percent 2010
# 102  2010                 AK                       3.668216e+06      0.001443
# 103  2010                 AL                       8.571505e+07      0.033716
# 104  2010                 AR                       3.616419e+07      0.014225
# 105  2010                 AZ                       6.105057e+07      0.024014
# 106  2010                 CA                       5.222043e+07      0.020541

# %%
# Normalize data for year 2010 between 0 and 1 for map comparisons 

# Create e, where e the 'scores' column's values as floats
e_2010 = em_2010[['Percent 2010']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
e_2010_scaled = min_max_scaler.fit_transform(e_2010)


em_2010['Normalized Percent 2010']= e_2010_scaled

em_2010.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Year State abbreviation  State annual CO2 emissions (tons)  Percent 2010  \
# 102  2010                 AK                       3.668216e+06      0.001443
# 103  2010                 AL                       8.571505e+07      0.033716
# 104  2010                 AR                       3.616419e+07      0.014225
# 105  2010                 AZ                       6.105057e+07      0.024014
# 106  2010                 CA                       5.222043e+07      0.020541
#
#      Normalized Percent 2010
# 102                 0.013988
# 103                 0.327678
# 104                 0.138230
# 105                 0.233378
# 106                 0.199618

# %%
# Choropleth US Map Plot for Year 2010 - CO2 EMISSIONS

df = em_2010

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['State abbreviation'] + '<br>' +\
    'State annual CO2 emissions (tons) '+df['State annual CO2 emissions (tons)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2010']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['State abbreviation'],
        z = df['Normalized Percent 2010'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2010 CO2 Emissions - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/84.embed" height="525px" width="100%"></iframe>

# %%
# Isolate to year 2014
em_2014 = reorg_em.loc[reorg_em["Year"] == 2014, :]
em_2014.head()
# Out:
#      Year State abbreviation  State annual CO2 emissions (tons)
# 153  2014                 AK                       2.407768e+06
# 154  2014                 AL                       7.173797e+07
# 155  2014                 AR                       3.612195e+07
# 156  2014                 AZ                       5.515062e+07
# 157  2014                 CA                       4.969068e+07

# %%
# Calculate percent of US total
em_2014['Percent 2014']= em_2014['State annual CO2 emissions (tons)']/em_2014['State annual CO2 emissions (tons)'].sum()
em_2014.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Year State abbreviation  State annual CO2 emissions (tons)  Percent 2014
# 153  2014                 AK                       2.407768e+06      0.001151
# 154  2014                 AL                       7.173797e+07      0.034301
# 155  2014                 AR                       3.612195e+07      0.017272
# 156  2014                 AZ                       5.515062e+07      0.026370
# 157  2014                 CA                       4.969068e+07      0.023759

# %%
# Normalize data for year 2014 between 0 and 1 for map comparisons 

# Create e, where e the 'scores' column's values as floats
e_2014 = em_2014[['Percent 2014']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
e_2014_scaled = min_max_scaler.fit_transform(e_2014)


em_2014['Normalized Percent 2014']= e_2014_scaled

em_2014.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Year State abbreviation  State annual CO2 emissions (tons)  Percent 2014  \
# 153  2014                 AK                       2.407768e+06      0.001151
# 154  2014                 AL                       7.173797e+07      0.034301
# 155  2014                 AR                       3.612195e+07      0.017272
# 156  2014                 AZ                       5.515062e+07      0.026370
# 157  2014                 CA                       4.969068e+07      0.023759
#
#      Normalized Percent 2014
# 153                 0.010027
# 154                 0.303177
# 155                 0.152581
# 156                 0.233041
# 157                 0.209954

# %%
# Choropleth US Map Plot for Year 2014 - CO2 EMISSIONS

df = em_2014

for col in df.columns:
    df[col] = df[col].astype(str)
    
df['text'] = df['State abbreviation'] + '<br>' +\
    'State annual CO2 emissions (tons) '+df['State annual CO2 emissions (tons)']+'<br>'+\
    'Percent of U.S. Total '+df['Percent 2014']

data = [ dict(
        type='choropleth',
        autocolorscale = True,
        zmin = 0,
        zmax = 1,
        locations = df['State abbreviation'],
        z = df['Normalized Percent 2014'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Data Normalized between 0 and 1")
        ) ]

layout = dict(
        title = '2014 CO2 Emissions - Percent of U.S. Total (Hover for actuals)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jherronplahn/86.embed" height="525px" width="100%"></iframe>
